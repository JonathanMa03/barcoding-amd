# %%
# TEST SETUP

# cd external/octvision3d
# pip install -e .
# cd nnUNet
# pip install -e .
# nnUNetv2_train --help

# setx nnUNet_raw "C:\Users\u0667281\Desktop\JMA\barcoding-amd\external\OCTAVE\nnUNet_raw"
# setx nnUNet_preprocessed "C:\Users\u0667281\Desktop\JMA\barcoding-amd\external\OCTAVE\nnUNet_preprocessed"
# setx nnUNet_results "C:\Users\u0667281\Desktop\JMA\barcoding-amd\external\OCTAVE\nnUNet_results"

# %%
import os
from pathlib import Path

path_names = [
    "nnUNet_raw",
    "nnUNet_preprocessed",
    "nnUNet_results",
]

for name in path_names:
    value = os.environ.get(name)
    print(f"{name}: {value}")

    if value is not None:
        path = Path(value)
        print(f"  Exists: {path.exists()}")

# %%
import sys
import torch
import nnunetv2
import octvision3d

print("Python:", sys.executable)
print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("nnU-Net:", nnunetv2.__file__)
print("OCTVision3D:", octvision3d.__file__)

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
